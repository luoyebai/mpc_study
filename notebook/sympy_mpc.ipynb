# %% [markdown]
# - [Reference video](https://www.bilibili.com/video/BV1Y44y1b7ke/)
# - State-transition equation:
# $$x(k+1)=\underbrace{A}_{n \times n}\underbrace{x(k)}_{n \times 1}+\underbrace{B}_{n \times p}\underbrace{u(k)}_{p \times 1}$$
# - Prediction horizon function:
# $$
# X(k)=Mx(k) + CU(k)
# $$
# - In this function(N is horizon)
# $$
# X(k) =
# \underbrace{
# \begin{bmatrix}
# x(k|k) \\
# x(k+1|k) \\
# \vdots \\
# x(k+i|k) \\
# \vdots \\
# x(k+N|k) \\
# \end{bmatrix}
# }_{n(N+1) \times 1}
# \quad \\
# U(k)=
# \underbrace{
# \begin{bmatrix}
# u(k|k) \\
# u(k+1|k) \\
# \vdots \\
# u(k+i|k) \\
# \vdots \\
# u(k+N-1|k) \\
# \end{bmatrix}
# }_{Np \times 1}
# \quad \\
# M =
# \underbrace{
# \begin{bmatrix}
# I_{n \times n} \\
# A_{n \times n} \\
# A_2 \\
# \vdots \\
# A_N \\
# \end{bmatrix}
# }_{n(N+1) \times n}
# \quad \\
# C =
# \underbrace{
# \begin{bmatrix}
# 0 & 0 & \cdots & 0 \\
# \vdots & \vdots & \cdots & \vdots \\
# 0 & 0 & & 0 \\
# B & 0 & \cdots & 0 \\
# AB & B & \cdots & 0 \\
# \vdots & \vdots & \ddots & 0 \\
# A^{N-1}B & A^{N-2}B & \cdots & B \\
# \end{bmatrix}
# }_{n(N+1) \times Np}
# $$

# %% [markdown]
# - Cost function:
# $$
# J = (MX_k+CU_k-x^*)^T\overline{Q}(MX_k+CU_k-x^*) + (U_k)^T\overline{R}(U_k)
# $$
# - In this funciton
# - $Q(error),R(input)$ are adjustment matrixs
# $$
# \overline{Q} =
# \begin{bmatrix}
# Q & \cdots & 0 \\
# \vdots & Q & \vdots \\
# 0 & \cdots & F \\
# \end{bmatrix}
# \quad \\
# \overline{R} =
# \begin{bmatrix}
# R & \cdots & 0 \\
# \vdots & \ddots & \vdots \\
# 0  & \cdots & R \\
# \end{bmatrix}
# $$

# %%
# install package
# !pip3 install sympy numpy matplotlib casadi
# Out:
# Requirement already satisfied: sympy in /home/luoyebai/.conda/envs/cling/lib/python3.12/site-packages (1.12)
# Requirement already satisfied: numpy in /home/luoyebai/.conda/envs/cling/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /home/luoyebai/.conda/envs/cling/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: casadi in /home/luoyebai/.conda/envs/cling/lib/python3.12/site-packages (3.6.6)
# Requirement already satisfied: mpmath>=0.19 in /home/luoyebai/.conda/envs/cling/lib/python3.12/site-packages (from sympy) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/luoyebai/.conda/envs/cling/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/luoyebai/.conda/envs/cling/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/luoyebai/.conda/envs/cling/lib/python3.12/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/luoyebai/.conda/envs/cling/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/luoyebai/.conda/envs/cling/lib/python3.12/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /home/luoyebai/.conda/envs/cling/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/luoyebai/.conda/envs/cling/lib/python3.12/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/luoyebai/.conda/envs/cling/lib/python3.12/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/luoyebai/.conda/envs/cling/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import sympy


def M(N: int, A: sympy.Matrix):
    return sympy.BlockMatrix([[sympy.Matrix(A**i)] for i in range(N + 1)]).as_explicit()


def C(N: int, A: sympy.Matrix, B: sympy.Matrix):
    n, p = (A * B).shape
    res_up = sympy.BlockMatrix([[sympy.zeros(n, p) for i in range(N)]]).as_explicit()
    res_down = sympy.BlockMatrix(
        [
            [
                A ** (N - j) * (A ** (N - i)).inv() * B if i >= j else sympy.zeros(n, p)
                for j in range(N)
            ]
            for i in range(N)
        ]
    ).as_explicit()
    return sympy.BlockMatrix([[res_up], [res_down]]).as_explicit()


def Q_BAR(N: int, Q: sympy.Matrix, F: sympy.Matrix):
    return sympy.BlockDiagMatrix(*([Q for _ in range(N)] + [F])).as_explicit()


def R_BAR(N: int, R: sympy.Matrix):
    return sympy.BlockDiagMatrix(*([R for _ in range(N)])).as_explicit()


def AssertShape(name: str, mat, shape):
    assert mat.shape == shape, f"{name} shape {mat.shape} != {shape} error"
def AssertDigMat(name:str,mat:sympy.Matrix):
    assert mat.is_diagonal() ,f"{name} is not diagonal matrix"

# %% [markdown]
# - ex($n,p=2,2$):
#
# $$
# \begin{bmatrix}
# x_1(k+1) \\
# x_2(k+1) \\
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1  & 0.1 \\
# -1  & -2 \\
# \end{bmatrix}
# \begin{bmatrix}
# x_1(k) \\
# x_2(k) \\
# \end{bmatrix}
# +
# \begin{bmatrix}
# 0.2 & 1 \\
# 0.5 & 2 \\
# \end{bmatrix}u(k)
# $$

# %%
import numpy

# State,input dimensions
n, p = 2, 2
# Prediction horizon
N = 10
# run 100 step
steps = 100
# incremental control
inc_control = True

"""
# Also use symbolic calculations to view the results
# All results are symbols rather than numbers
# Example:
A_SYM = sympy.MatrixSymbol("A", n, n)
B_SYM = sympy.MatrixSymbol("B", n, p)
Q_SYM = sympy.MatrixSymbol("Q", n, n)
F_SYM = sympy.MatrixSymbol("F", n, n)
R_SYM = sympy.MatrixSymbol("R", p, p)
"""
# State transition matrix
A_VAL = sympy.Matrix([[1, 0.1], [-1, 2]])  # nxn
B_VAL = sympy.Matrix([[0.2, 1], [0.5, 2]])  # nxp
# Adjustment matrix
Q_VAL = sympy.Matrix([[100, 0], [0, 100]])  # nxn
F_VAL = sympy.Matrix([[100, 0], [0, 100]])  # nxn
R_VAL = sympy.Matrix([[0.1, 0], [0, 0.1]])  # pxp

# state init
X = numpy.array([[[20], [-20]]])
x_target = numpy.array([[400], [-400]])
# x_target = numpy.array([[-80], [40]])

# input init
U = numpy.array([numpy.zeros((p, 1))])

# upper limit
u_ubg = numpy.array([1e10, 1e10])
# u_ubg = numpy.array([numpy.inf, numpy.inf])
# lower limit
u_lbg = numpy.array([-1e10, -1e10])
# u_lbg = numpy.array([-numpy.inf, -numpy.inf])

# assert state transition  matrix
AssertShape("A", A_VAL, (n, n))
AssertShape("B", B_VAL, (n, p))
# assert adjustment matrix
AssertShape("Q", Q_VAL, (n, n))
AssertShape("F", F_VAL, (n, n))
AssertShape("R", R_VAL, (p, p))
AssertDigMat("Q", Q_VAL)
AssertDigMat("F", F_VAL)
AssertDigMat("R", R_VAL)


AssertShape("X", X, (1, n, 1))
AssertShape("Target", x_target, (n, 1))

AssertShape("U", U, (1, p, 1))
AssertShape("u_ubg", u_ubg, (p,))
AssertShape("u_lbg", u_lbg, (p,))

# %%
import casadi

Q_BAR_VAL = Q_BAR(N, Q_VAL, F_VAL)
R_BAR_VAL = R_BAR(N, R_VAL)

C_VAL = C(N, A_VAL, B_VAL)
M_VAL = M(N, A_VAL)

# use numpy
A_NP = numpy.array(A_VAL).astype(numpy.float64)
B_NP = numpy.array(B_VAL).astype(numpy.float64)

C_NP = numpy.array(C_VAL).astype(numpy.float64)
M_NP = numpy.array(M_VAL).astype(numpy.float64)

Q_BAR_NP = numpy.array(Q_BAR_VAL).astype(numpy.float64)
R_BAR_NP = numpy.array(R_BAR_VAL).astype(numpy.float64)

X_TARGET = numpy.zeros((N + 1) * n)

for i in range(n):
    X_TARGET[:: (i + 1)] = x_target[n - i - 1]
X_TARGET = X_TARGET.reshape(((N + 1) * n), 1)

# U_SYM = casadi.SX.sym("U", N * p)
U_SYM = casadi.MX.sym("U", N * p)

if inc_control:
    U_INC = casadi.MX.zeros(N * p)


constraints = [U_SYM]
ubg = casadi.vertcat(*[u_ubg for _ in range(N)])
lbg = casadi.vertcat(*[u_lbg for _ in range(N)])

U_START = numpy.zeros((N * p, 1))

for i in range(steps):
    XK = M_NP @ X[-1] - X_TARGET + C_NP @ U_SYM

    if inc_control:
        U_INC[0:p] = U_SYM[0:p] - U[-1]
        U_INC[p : p * N] = U_SYM[p : p * N] - U_SYM[0 : p * (N - 1)]
        J_NP = XK.T @ Q_BAR_NP @ XK + U_INC.T @ R_BAR_NP @ U_INC
    else:
        J_NP = XK.T @ Q_BAR_NP @ XK + U_SYM.T @ R_BAR_NP @ U_SYM

    solver = casadi.nlpsol(
        "mpc_solver",
        "ipopt",
        {"x": U_SYM, "f": J_NP, "g": casadi.vertcat(*constraints)},
        {"ipopt.print_level": 0, "print_time": False},
    )
    u_i = solver(x0=U_START, lbg=lbg, ubg=ubg)["x"].toarray()[:p]
    new_state = numpy.array([A_NP @ X[-1] + B_NP @ u_i]).astype(numpy.float64)
    U = numpy.append(U, numpy.array([u_i]), axis=0)
    X = numpy.append(X, new_state, axis=0)
# display(X,U)
# Out:
# array([[[  20.        ],
#         [ -20.        ]],
#
#        [[ 168.12884888],
#         [-283.75026841]],
#
#        [[ 333.65577438],
#         [-359.664483  ]],
#
#        [[ 399.95384756],
#         [-394.90900564]]])
# array([[[    0.        ],
#         [    0.        ]],
#
#        [[-5240.07966166],
#         [ 1198.14478121]],
#
#        [[ -118.39001991],
#         [  217.57995633]],
#
#        [[ 4535.46691792],
#         [ -804.82886211]]])

# %%
import matplotlib.pyplot as plt

k = numpy.linspace(0, steps + 1, steps + 1)

colors = [
    "red",
    "blue",
    "green",
    "orange",
    "purple",
    "brown",
    "black",
]

for i in range(n):
    xi = X[:, i, 0]
    color = colors[i % len(colors)]
    plt.plot(k, xi, label=f"x{i+1}", color=color)
    plt.axhline(y=x_target[i], linestyle="--", label=f"x{i+1} target", color=color)

plt.title("MPC-state")
plt.xlabel("steps")
plt.ylabel("state val")
plt.legend()
plt.grid()

plt.figure()

U = U[1:]
for i in range(p):
    color = colors[i % len(colors)]
    ui = U[:, i]
    plt.plot(k[:-1], ui, label=f"u{i+1}", color=color)
    plt.axhline(y=u_lbg[i], color=color, linestyle=":", label=f"u{i+1} lower limit")
    plt.axhline(y=u_ubg[i], color=color, linestyle="--", label=f"u{i+1} upper limit")

plt.title("MPC-input")
plt.xlabel("steps")
plt.ylabel("input val")
plt.legend()
plt.grid()

plt.show()
